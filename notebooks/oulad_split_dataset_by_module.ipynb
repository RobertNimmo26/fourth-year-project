# %% [markdown]
# # Oulad Split Dataset By Module

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import GDrive files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd 'drive/My Drive/Colab Notebooks/4th year project/OULAD dataset/Deadline'
# Out:
# /content/drive/My Drive/Colab Notebooks/4th year project/OULAD dataset/Deadline

# %%
ls
# Out:
# 120/               oulad_BBB_120.csv  oulad_DDD_180.csv  oulad_FFF_180.csv
# 150/               oulad_BBB_150.csv  oulad_DDD_210.csv  oulad_FFF_210.csv
# 180/               oulad_BBB_180.csv  oulad_DDD_240.csv  oulad_FFF_240.csv
# 210/               oulad_BBB_210.csv  oulad_DDD_270.csv  oulad_FFF_270.csv
# 240/               oulad_BBB_240.csv  oulad_DDD_60.csv   oulad_FFF_60.csv
# 270/               oulad_BBB_270.csv  oulad_DDD_90.csv   oulad_FFF_90.csv
# 30/                oulad_BBB_90.csv   oulad_EEE_120.csv  oulad_GGG_120.csv
# 60/                oulad_CCC_120.csv  oulad_EEE_150.csv  oulad_GGG_150.csv
# 90/                oulad_CCC_150.csv  oulad_EEE_180.csv  oulad_GGG_180.csv
# oulad_AAA_120.csv  oulad_CCC_180.csv  oulad_EEE_210.csv  oulad_GGG_210.csv
# oulad_AAA_150.csv  oulad_CCC_210.csv  oulad_EEE_240.csv  oulad_GGG_240.csv
# oulad_AAA_180.csv  oulad_CCC_240.csv  oulad_EEE_270.csv  oulad_GGG_270.csv
# oulad_AAA_210.csv  oulad_CCC_270.csv  oulad_EEE_60.csv   oulad_GGG_60.csv
# oulad_AAA_240.csv  oulad_CCC_90.csv   oulad_EEE_90.csv   oulad_GGG_90.csv
# oulad_AAA_270.csv  oulad_DDD_120.csv  oulad_FFF_120.csv
# oulad_AAA_90.csv   oulad_DDD_150.csv  oulad_FFF_150.csv

# %% [markdown]
# ### Load dataset and split by module

# %%
deadline_list = [i for i in range(0,271,10)]

# %%
for deadline in deadline_list:
  oulad_dataset_combined_df = pd.read_csv(f'../../OULAD dataset/Deadline/{deadline}/oulad_dataset_combined_{deadline}.csv')
  modules = oulad_dataset_combined_df.code_module.unique()
  for module in modules:
    module_df = oulad_dataset_combined_df.loc[oulad_dataset_combined_df['code_module'] == module]
    print(f"Module {module}")
    print(module_df['code_presentation'].value_counts())
    print("")
    module_df.drop('code_module', axis=1)
    module_df.to_csv(f'{deadline}/oulad_{module}_{deadline}.csv', index=False)
# Out:
# Module AAA
# 2013J    308
# 2014J    292
# Name: code_presentation, dtype: int64
#
# Module BBB
# 2014J    1497
# 2013J    1491
# 2013B    1188
# 2014B    1059
# Name: code_presentation, dtype: int64
#
# Module CCC
# 2014J    1299
# 2014B     941
# Name: code_presentation, dtype: int64
#
# Module DDD
# 2013J    1180
# 2014J    1078
# 2013B     803
# 2014B     684
# Name: code_presentation, dtype: int64
#
# Module EEE
# 2014J    823
# 2013J    744
# 2014B    493
# Name: code_presentation, dtype: int64
#
# Module FFF
# 2013J    1512
# 2014J    1416
# 2013B    1116
# 2014B     964
# Name: code_presentation, dtype: int64
#
# Module GGG
# 2013J    770
# 2014B    665
# 2014J    568
# Name: code_presentation, dtype: int64
#
# Module AAA
# 2013J    309
# 2014J    292
# Name: code_presentation, dtype: int64
#
# Module BBB
# 2013J    1519
# 2014J    1504
# 2013B    1196
# 2014B    1076
# Name: code_presentation, dtype: int64
#
# Module CCC
# 2014J    1304
# 2014B     942
# Name: code_presentation, dtype: int64
#
# Module DDD
# 2013J    1180
# 2014J    1080
# 2013B     804
# 2014B     687
# Name: code_presentation, dtype: int64
#
# Module EEE
# 2014J    826
# 2013J    752
# 2014B    496
# Name: code_presentation, dtype: int64
#
# Module FFF
# 2013J    1514
# 2014J    1420
# 2013B    1118
# 2014B     968
# Name: code_presentation, dtype: int64
#
# Module GGG
# 2013J    825
# 2014B    693
# 2014J    592
# Name: code_presentation, dtype: int64
#
# Module AAA
# 2013J    309
# 2014J    292
# Name: code_presentation, dtype: int64
#
# Module BBB
# 2013J    1520
# 2014J    1506
# 2013B    1198
# 2014B    1077
# Name: code_presentation, dtype: int64
#
# Module CCC
# 2014J    1305
# 2014B     942
# Name: code_presentation, dtype: int64
#
# Module DDD
# 2013J    1180
# 2014J    1080
# 2013B     805
# 2014B     687
# Name: code_presentation, dtype: int64
#
# Module EEE
# 2014J    827
# 2013J    754
# 2014B    496
# Name: code_presentation, dtype: int64
#
# Module FFF
# 2013J    1514
# 2014J    1421
# 2013B    1118
# 2014B     968
# Name: code_presentation, dtype: int64
#
# Module GGG
# 2013J    836
# 2014B    703
# 2014J    597
# Name: code_presentation, dtype: int64
#
# Module AAA
# 2013J    309
# 2014J    292
# Name: code_presentation, dtype: int64
#
# Module BBB
# 2013J    1526
# 2014J    1508
# 2013B    1198
# 2014B    1078
# Name: code_presentation, dtype: int64
#
# Module CCC
# 2014J    1307
# 2014B     942
# Name: code_presentation, dtype: int64
#
# Module DDD
# 2013J    1183
# 2014J    1083
# 2013B     805
# 2014B     687
# Name: code_presentation, dtype: int64
#
# Module EEE
# 2014J    828
# 2013J    754
# 2014B    496
# Name: code_presentation, dtype: int64
#
# Module FFF
# 2013J    1514
# 2014J    1423
# 2013B    1119
# 2014B     968
# Name: code_presentation, dtype: int64
#
# Module GGG
# 2013J    842
# 2014B    704
# 2014J    599
# Name: code_presentation, dtype: int64
#
# Module AAA
# 2013J    309
# 2014J    292
# Name: code_presentation, dtype: int64
#
# Module BBB
# 2013J    1530
# 2014J    1508
# 2013B    1198
# 2014B    1078
# Name: code_presentation, dtype: int64
#
# Module CCC
# 2014J    1307
# 2014B     942
# Name: code_presentation, dtype: int64
#
# Module DDD
# 2013J    1183
# 2014J    1084
# 2013B     806
# 2014B     687
# Name: code_presentation, dtype: int64
#
# Module EEE
# 2014J    828
# 2013J    754
# 2014B    496
# Name: code_presentation, dtype: int64
#
# Module FFF
# 2013J    1515
# 2014J    1423
# 2013B    1119
# 2014B     968
# Name: code_presentation, dtype: int64
#
# Module GGG
# 2013J    846
# 2014B    704
# 2014J    602
# Name: code_presentation, dtype: int64
#
# Module AAA
# 2013J    309
# 2014J    292
# Name: code_presentation, dtype: int64
#
# Module BBB
# 2013J    1531
# 2014J    1508
# 2013B    1198
# 2014B    1078
# Name: code_presentation, dtype: int64
#
# Module CCC
# 2014J    1307
# 2014B     943
# Name: code_presentation, dtype: int64
#
# Module DDD
# 2013J    1183
# 2014J    1085
# 2013B     806
# 2014B     687
# Name: code_presentation, dtype: int64
#
# Module EEE
# 2014J    828
# 2013J    754
# 2014B    496
# Name: code_presentation, dtype: int64
#
# Module FFF
# 2013J    1515
# 2014J    1423
# 2013B    1119
# 2014B     968
# Name: code_presentation, dtype: int64
#
# Module GGG
# 2013J    847
# 2014B    704
# 2014J    603
# Name: code_presentation, dtype: int64
#
# Module AAA
# 2013J    309
# 2014J    292
# Name: code_presentation, dtype: int64
#
# Module BBB
# 2013J    1531
# 2014J    1508
# 2013B    1198
# 2014B    1078
# Name: code_presentation, dtype: int64
#
# Module CCC
# 2014J    1307
# 2014B     943
# Name: code_presentation, dtype: int64
#
# Module DDD
# 2013J    1183
# 2014J    1085
# 2013B     806
# 2014B     687
# Name: code_presentation, dtype: int64
#
# Module EEE
# 2014J    828
# 2013J    754
# 2014B    496
# Name: code_presentation, dtype: int64
#
# Module FFF
# 2013J    1515
# 2014J    1423
# 2013B    1119
# 2014B     968
# Name: code_presentation, dtype: int64
#
# Module GGG
# 2013J    847
# 2014B    704
# 2014J    604
# Name: code_presentation, dtype: int64
#
# Module AAA
# 2013J    309
# 2014J    292
# Name: code_presentation, dtype: int64
#
# Module BBB
# 2013J    1533
# 2014J    1508
# 2013B    1199
# 2014B    1078
# Name: code_presentation, dtype: int64
#
# Module CCC
# 2014J    1307
# 2014B     943
# Name: code_presentation, dtype: int64
#
# Module DDD
# 2013J    1183
# 2014J    1085
# 2013B     806
# 2014B     687
# Name: code_presentation, dtype: int64
#
# Module EEE
# 2014J    828
# 2013J    754
# 2014B    496
# Name: code_presentation, dtype: int64
#
# Module FFF
# 2013J    1515
# 2014J    1424
# 2013B    1119
# 2014B     968
# Name: code_presentation, dtype: int64
#
# Module GGG
# 2013J    847
# 2014B    704
# 2014J    604
# Name: code_presentation, dtype: int64
#
# Module AAA
# 2013J    309
# 2014J    292
# Name: code_presentation, dtype: int64
#
# Module BBB
# 2013J    1533
# 2014J    1508
# 2013B    1199
# 2014B    1078
# Name: code_presentation, dtype: int64
#
# Module CCC
# 2014J    1307
# 2014B     943
# Name: code_presentation, dtype: int64
#
# Module DDD
# 2013J    1183
# 2014J    1085
# 2013B     806
# 2014B     687
# Name: code_presentation, dtype: int64
#
# Module EEE
# 2014J    828
# 2013J    754
# 2014B    496
# Name: code_presentation, dtype: int64
#
# Module FFF
# 2013J    1515
# 2014J    1424
# 2013B    1119
# 2014B     968
# Name: code_presentation, dtype: int64
#
# Module GGG
# 2013J    847
# 2014B    704
# 2014J    604
# Name: code_presentation, dtype: int64
